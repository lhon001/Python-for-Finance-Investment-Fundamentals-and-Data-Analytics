# %% [markdown]
# Importing and Organizing Your Data

# %%
import numpy as np
import pandas as pd

# %%
ser = pd.Series(np.random.random(5), name = "Column 01")

# %%
ser
# Out:
# 0    0.988451
# 1    0.682169
# 2    0.679814
# 3    0.109351
# 4    0.238356
# Name: Column 01, dtype: float64

# %%
ser[2]
# Out:
# 0.6798135100661221

# %%
from pandas_datareader import data as wb

# %%
PG = wb.DataReader('PG', data_source='yahoo', start='2017-1-1')

# %%
PG
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-01-03   84.389999   83.500000   83.879997   84.199997   8792700.0
# 2017-01-04   84.599998   84.239998   84.449997   84.500000   8096700.0
# 2017-01-05   85.430000   84.379997   84.410004   85.059998   6852400.0
# 2017-01-06   85.250000   84.620003   84.940002   85.029999   4799900.0
# 2017-01-09   84.660004   83.750000   84.059998   84.400002  10981100.0
# 2017-01-10   84.430000   83.239998   84.339996   83.489998  10918200.0
# 2017-01-11   83.750000   83.279999   83.389999   83.750000   9572300.0
# 2017-01-12   83.879997   83.370003   83.709999   83.839996   6545400.0
# 2017-01-13   84.019997   83.440002   83.849998   84.010002   6762800.0
# 2017-01-17   85.580002   83.879997   83.900002   85.209999  13097600.0
# 2017-01-18   85.300003   84.589996   84.800003   84.930000  10520400.0
# 2017-01-19   85.000000   84.279999   84.629997   84.699997  14074500.0
# ...

# %%
PG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 582 entries, 2017-01-03 to 2019-04-26
# Data columns (total 6 columns):
# High         582 non-null float64
# Low          582 non-null float64
# Open         582 non-null float64
# Close        582 non-null float64
# Volume       582 non-null float64
# Adj Close    582 non-null float64
# dtypes: float64(6)
# memory usage: 31.8 KB

# %%
PG.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-01-03  84.389999  83.500000  83.879997  84.199997   8792700.0  77.700050
# 2017-01-04  84.599998  84.239998  84.449997  84.500000   8096700.0  77.976891
# 2017-01-05  85.430000  84.379997  84.410004  85.059998   6852400.0  78.493637
# 2017-01-06  85.250000  84.620003  84.940002  85.029999   4799900.0  78.465958
# 2017-01-09  84.660004  83.750000  84.059998  84.400002  10981100.0  77.884605

# %%
  PG.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2019-04-22  107.199997  105.739998  106.129997  106.010002   9057200.0
# 2019-04-23  104.110001  102.129997  104.010002  103.160004  15979800.0
# 2019-04-24  104.650002  102.790001  103.320000  103.690002  10094800.0
# 2019-04-25  103.570000  102.589996  103.099998  103.279999   6085300.0
# 2019-04-26  105.879997  103.910004  103.949997  105.860001   7747400.0
#
#              Adj Close
# Date
# 2019-04-22  106.010002
# 2019-04-23  103.160004
# 2019-04-24  103.690002
# 2019-04-25  103.279999
# 2019-04-26  105.860001

# %%
tickers = ['PG', 'MSFT', 'T', 'F', 'GE']
new_data = pd.DataFrame() 
for t in tickers:
    new_data[t] = wb.DataReader(t, data_source='iex', start='2015-1-1')['close']

# %%
new_data.tail()
# Out:
#                     PG        MSFT          T      F    GE
# Date
# 2019-04-22  106.010002  123.760002  32.080002   9.35  9.32
# 2019-04-23  103.160004  125.440002  32.099998   9.50  9.33
# 2019-04-24  103.690002  125.010002  30.790001   9.57  9.32
# 2019-04-25  103.279999  129.149994  30.340000   9.40  9.12
# 2019-04-26  105.860001  129.889999  30.680000  10.41  9.57

# %%
Tesla = wb.DataReader('TSLA', data_source='yahoo', start='2017-1-1')

# %%
Tesla
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2017-01-03  220.330002  210.960007  214.860001  216.990005   5923300
# 2017-01-04  228.000000  214.309998  214.750000  226.990005  11213500
# 2017-01-05  227.479996  221.949997  226.419998  226.750000   5911700
# 2017-01-06  230.309998  225.449997  226.929993  229.009995   5527900
# 2017-01-09  231.919998  228.000000  228.970001  231.279999   3957000
# 2017-01-10  232.000000  226.889999  232.000000  229.869995   3660000
# 2017-01-11  229.979996  226.679993  229.070007  229.729996   3650800
# 2017-01-12  230.699997  225.580002  229.059998  229.589996   3790200
# 2017-01-13  237.850006  229.589996  230.000000  237.750000   6093000
# 2017-01-17  239.960007  234.369995  236.699997  235.580002   4611900
# 2017-01-18  239.710007  235.580002  236.649994  238.360001   3769000
# 2017-01-19  248.679993  240.750000  247.250000  243.759995   7732300
# ...
